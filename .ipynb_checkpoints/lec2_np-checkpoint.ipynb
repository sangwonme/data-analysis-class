# %% [markdown]
# # Numpy
# * 행렬 연산을 쉽게 할 수 있도록 해주는 패키지
# * https://numpy.org/doc/stable/
# ---
# ### 오늘 배울 것
# 1. numpy array란?
# 2. shape, indexing
# 3. pandas DataFrame을 numpy array로 변환하기
# 4. 다양한 연산들

# %%
import numpy as np

# %%
arr = np.random.rand(6, 4)
arr
# Out:
# array([[0.30635138, 0.55569143, 0.88867967, 0.27400027],
#        [0.95139938, 0.93822365, 0.55750885, 0.56979446],
#        [0.76683012, 0.93891916, 0.5138271 , 0.69698698],
#        [0.45529401, 0.923447  , 0.40908596, 0.23241705],
#        [0.13595753, 0.03850899, 0.00198342, 0.10355565],
#        [0.73469941, 0.14813994, 0.18736509, 0.58821832]])

# %%
# get dimension of array
arr.shape
# Out:
# (6, 4)

# %%
# selecting indecies of array
print(arr[:, 3])
print('--------------------------------------------------------------------')
print(arr[1, 1])
print('--------------------------------------------------------------------')
print(arr[0, :])
print('--------------------------------------------------------------------')
print(arr[:2, :3])
print('--------------------------------------------------------------------')
print(arr[[1, 3], 2])
# Out:
# [0.27400027 0.56979446 0.69698698 0.23241705 0.10355565 0.58821832]
# --------------------------------------------------------------------
# 0.9382236514358833
# --------------------------------------------------------------------
# [0.30635138 0.55569143 0.88867967 0.27400027]
# --------------------------------------------------------------------
# [[0.30635138 0.55569143 0.88867967]
#  [0.95139938 0.93822365 0.55750885]]
# --------------------------------------------------------------------
# [0.55750885 0.40908596]

# %%
import pandas as pd

# Read file (txt file)
table = pd.read_csv('./data/sample_01.txt', delimiter='\t')
table = table.set_index('ID_REF')
table
# Out:
#                  GSM437093  GSM437094  GSM437095  GSM437096  GSM437097  \
# ID_REF
# 1007_s_at        11.658060  11.627632  11.209226  11.770620  11.097194
# 1053_at           8.845589   8.625595   8.234096   8.727833   8.521389
# 117_at            7.450960   7.342564   8.122719   7.285359   7.820522
# 121_at            9.907034   9.957431   9.889233   9.594032   9.551032
# 1255_g_at         4.891556   4.898858   4.769176   4.841742   4.802824
# ...                    ...        ...        ...        ...        ...
# AFFX-ThrX-5_at    5.032084   5.206966   5.101839   5.029609   5.077259
# AFFX-ThrX-M_at    4.229997   4.201268   4.196534   4.231171   4.116369
# AFFX-TrpnX-3_at   4.347058   4.382307   4.243317   4.345005   4.249124
# AFFX-TrpnX-5_at   4.993825   5.114724   4.874280   5.065885   5.017324
# AFFX-TrpnX-M_at   4.700877   4.882003   4.683801   4.800876   4.686600
#
#                  GSM437098  GSM437099  GSM437100  GSM437101  GSM437102  ...  \
# ID_REF                                                                  ...
# 1007_s_at        11.217040  11.480605  11.174613  11.157401  11.215819  ...
# 1053_at           8.812260   8.578217   8.408970   9.016806   8.548101  ...
# 117_at            7.513008   7.595940   7.606444   7.343781   8.775246  ...
# 121_at            9.682159   9.951888   9.678011   9.826328   9.693594  ...
# 1255_g_at         5.104819   4.877827   4.894545   4.927487   5.051599  ...
# ...                    ...        ...        ...        ...        ...  ...
# AFFX-ThrX-5_at    5.070331   5.063159   5.156025   5.323390   4.962910  ...
# AFFX-ThrX-M_at    4.113683   4.162647   4.111047   4.174615   4.195413  ...
# AFFX-TrpnX-3_at   4.304094   4.368020   4.319885   4.303696   4.310372  ...
# AFFX-TrpnX-5_at   4.919401   5.033130   4.957373   5.089581   4.938037  ...
# AFFX-TrpnX-M_at   4.781757   4.812263   4.804145   4.742111   4.668298  ...
#
#                  GSM437260  GSM437261  GSM437262  GSM437263  GSM437264  \
# ID_REF
# 1007_s_at        10.558947  11.497468  11.664038  11.013572  11.784416
# 1053_at           8.669574   8.669394   8.848055   8.558723   9.522910
# 117_at            7.724462   7.440434   7.663952   7.822330   7.439561
# 121_at            9.832929  10.158157   9.844260   9.960091   9.785614
# 1255_g_at         4.867194   4.836543   5.160730   4.977262   4.908078
# ...                    ...        ...        ...        ...        ...
# AFFX-ThrX-5_at    5.091461   5.090788   5.272675   5.074819   5.168944
# AFFX-ThrX-M_at    4.208915   4.278785   4.159345   4.140330   4.213805
# AFFX-TrpnX-3_at   4.317787   4.296943   4.218003   4.259063   4.363395
# AFFX-TrpnX-5_at   5.110459   5.123039   5.171700   4.897923   5.115629
# AFFX-TrpnX-M_at   4.902506   4.848659   4.795573   4.706944   4.906521
#
#                  GSM437265  GSM437266  GSM437267  GSM437268  GSM437269
# ID_REF
# 1007_s_at        11.153646  11.263214  11.414354  11.233133  11.604788
# 1053_at           9.183248   8.537171   9.203837   9.139161   8.969117
# 117_at            7.642415   7.587165   7.608669   7.296488   7.427372
# 121_at            9.846085   9.890658   9.751073   9.874834   9.851839
# 1255_g_at         5.067716   5.054698   5.151886   4.891733   4.767123
# ...                    ...        ...        ...        ...        ...
# AFFX-ThrX-5_at    5.083529   5.066363   5.157796   5.335892   4.870529
# AFFX-ThrX-M_at    4.273698   4.232728   4.192871   4.214598   3.985525
# AFFX-TrpnX-3_at   4.329778   4.212011   4.238437   4.194034   4.182780
# AFFX-TrpnX-5_at   5.114106   5.132582   5.118535   5.141602   5.017383
# AFFX-TrpnX-M_at   4.789743   4.889841   4.979246   4.819547   4.780263
#
# [54675 rows x 177 columns]

# %%
# Make np array from DataFrame

df_arr = np.array(table.loc['1007_s_at'])
print(df_arr)
print('shape : {}'.format(df_arr.shape))
print('--------------------------------------------------------------------')
df_arr = np.array(table.iloc[:2, :3])
print(df_arr)
print('shape : {}'.format(df_arr.shape))
# Out:
# [11.65806001 11.62763245 11.20922635 11.77062023 11.09719369 11.21703978
#  11.48060517 11.17461338 11.15740074 11.21581862 11.51351401 11.55347172
#  11.27166397 11.27834819 11.53304493 11.30160368 11.06511656 10.56564286
#  11.65840705 10.99288223 11.38937222 11.38189053 11.30510026 11.78160567
#  11.60236532 10.9635526  11.52013112 11.30543543 11.52316758 11.56479249
#  11.28864141 11.71613445 11.57913792 10.97763412 11.1252792  11.52859722
#  11.63241457 11.18680086 11.28721314 11.34328805 11.10550843 11.47100893
#  11.26547413 11.55765966 11.12726454 11.43800368 11.383763   11.43508286
#  11.14045412 11.36882297 10.8950259  11.72482451 11.2341227  10.94671741
#  11.90722048 10.96110234 11.44330592 10.92876877 11.49330637 11.09660443
#  11.16587355 11.52489246 10.86402874 11.07785031 11.11151232 11.7727096
#  11.67644763 11.02105134 11.39575926 11.19269875 11.51176274 11.37563908
#  11.21468481 11.13497148 11.14858416 11.6503364  11.15682674 11.5223139
#  10.89064292 11.60920103 12.02237559 11.74584083 11.28352108 11.34167144
#  11.2166535  10.9341658  11.15367017 11.6605271  11.29422055 11.68702538
#  11.69347162 11.38862188 11.57978743 11.49639656 11.53800982 11.90724058
#  11.90239881 11.16301472 11.50349098 11.62966185 11.22149024 11.93944399
#  11.35849648 10.96391545 12.1739105  11.14074616 11.58453702 11.39771596
#  11.13095699 11.70366    11.06740775 10.03047984 11.2825181  11.423484
#  11.00633687 11.33891455 11.17703045 11.2136815  11.27935141 11.09113121
#  11.41608982 11.10176093 11.61040848 11.53399448 11.27996095 11.62588938
#  11.4789002  11.183233   11.25115496 12.48499225 11.77111043 11.63342881
#  11.15613804 10.54274307 12.06287493 11.70489313 11.86370367 11.56589157
#  11.68514634 11.37792479 11.48567315 11.18781192 11.86123011 10.87530092
#  11.40714024 11.35216343 11.35394258 10.77442561 11.45379309 11.35611525
#  11.64049452 11.389352   11.89705661 11.15628384 11.31929402 11.28725907
#  11.31090997 10.80080172 11.58875827 11.29665523 11.62069933 10.72005475
#  11.19059937 11.50972555 11.57152744 11.64951126 11.62405366 10.55894684
#  11.49746781 11.66403777 11.01357156 11.78441573 11.15364591 11.26321358
#  11.41435383 11.23313335 11.60478809]
# shape : (177,)
# --------------------------------------------------------------------
# [[11.65806001 11.62763245 11.20922635]
#  [ 8.84558887  8.62559451  8.23409564]]
# shape : (2, 3)

# %%
# Arithmetic Operations

arr1 = np.random.rand(2, 3)
arr2 = np.random.rand(2, 3)

print('ARR 1')
print(arr1, end='\n\n')
print('Arr 2')
print(arr2)
print('--------------------------------------------------------------------')
print(arr1 + arr2)
print('--------------------------------------------------------------------')
print(arr1 - arr2)
print('--------------------------------------------------------------------')
print(arr1 * arr2)
print('--------------------------------------------------------------------')
print(arr1 / arr2)
# Out:
# ARR 1
# [[0.2421102  0.74578441 0.59172516]
#  [0.32135211 0.84912758 0.01442639]]
#
# Arr 2
# [[0.15132587 0.61009785 0.23655756]
#  [0.14562639 0.72819905 0.09699238]]
# --------------------------------------------------------------------
# [[0.39343607 1.35588226 0.82828272]
#  [0.46697849 1.57732664 0.11141877]]
# --------------------------------------------------------------------
# [[ 0.09078433  0.13568655  0.3551676 ]
#  [ 0.17572572  0.12092853 -0.08256599]]
# --------------------------------------------------------------------
# [[0.03663754 0.45500147 0.13997706]
#  [0.04679735 0.6183339  0.00139925]]
# --------------------------------------------------------------------
# [[1.59992602 1.2224013  2.50140038]
#  [2.20668877 1.16606521 0.14873736]]

# %%
# Operation : normalization

print(df_arr)
print('--------------------------------------------------------------------')
col_norm = np.linalg.norm(df_arr, axis=0).reshape(1,3)
print(col_norm)
cnorm_arr = df_arr / col_norm
print(cnorm_arr)
print('--------------------------------------------------------------------')
row_norm = np.linalg.norm(df_arr, axis=1).reshape(2,1)
print(row_norm)
rnorm_arr = df_arr / row_norm
print(rnorm_arr)
# Out:
# [[11.65806001 11.62763245 11.20922635]
#  [ 8.84558887  8.62559451  8.23409564]]
# --------------------------------------------------------------------
# [[14.63402903 14.47766269 13.90852567]]
# [[0.79664049 0.80314293 0.80592484]
#  [0.60445342 0.5957864  0.59201786]]
# --------------------------------------------------------------------
# [[19.91880907]
#  [14.84741237]]
# [[0.58527897 0.58375139 0.56274581]
#  [0.59576636 0.58094935 0.55458119]]

# %%
# TODO : Standardization

# YOUR CODE HERE

# %%
# TODO : log2

# YOUR CODE HERE
